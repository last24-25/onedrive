# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image in grayscale
image_path = r"D:\Series\Screenshot (114).png"  # Replace with your actual path
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if image is loaded properly
if image is None:
    print("Error: Image not found. Please check the file path.")
else:
    # Set threshold value
    threshold_value = 137

    # Apply binary thresholding
    used_threshold, segmented_image = cv2.threshold(image, threshold_value, 255, cv2.THRESH_BINARY)

    # Display original and segmented image using matplotlib
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(image, cmap='gray')
    plt.title("Original Image")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(segmented_image, cmap='gray')
    plt.title("Segmented Image (Thresholding)")
    plt.axis('off')

    plt.suptitle(f"Threshold Value Used: {used_threshold}", fontsize=12)
    plt.tight_layout()
    plt.show()
